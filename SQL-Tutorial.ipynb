# %% [markdown]
# # SQL
#
# The idea of this notebook is to provide a refresher on SQL for myself and to be more confortable uisnig SQL via python
#
# The outline will be:
# 1. Introduction to SQL and Databases
# * What is SQL? Explain the basics of SQL and its role in managing databases.
# * Types of Databases: Brief overview of relational databases (like PostgreSQL, MySQL) and why SQL is essential.
# * Setting up a Database: Guide on setting up a local database or using a cloud solution (e.g., SQLite, PostgreSQL, or a cloud database).
# 2. Using SQL in Python
# * SQL Libraries in Python:
# * sqlite3 for working with SQLite databases.
# * SQLAlchemy for an ORM approach.
# psycopg2 or PyMySQL for PostgreSQL or MySQL databases.
# * Connecting to Databases: Show how to connect to a local or cloud database using Python.
# 3. Basic SQL Operations
# * Create Tables:
#    * Syntax for CREATE TABLE in SQL.
#    * Use Python to create tables (using raw SQL and SQLAlchemy).
# * Insert Data:
#    * Syntax for INSERT INTO in SQL.
#    * Example of inserting data through Python.
# * Select Queries:
#    * Basic SELECT statements.
#    * Fetching data with Python and iterating over the results.
# * Update and Delete Operations:
#    * Syntax for UPDATE and DELETE in SQL.
#    * Modifying or removing records via Python.
# 4. Working with Larger Data
# * Joining Tables:
#    * Introduction to JOIN (INNER, LEFT, RIGHT) operations in SQL.
#    * Practical examples using Python.
# * Filtering and Sorting:
#    * Using WHERE, ORDER BY, and LIMIT in SQL.
#    * How Python can interact with filtered data.
# * Aggregate Functions:
#    * Functions like COUNT(), SUM(), AVG(), etc.
#    * Demonstrating the power of aggregations in Python.
# 5. Advanced Concepts
# * Indexing and Optimization:
#    * Overview of indexes and how they improve query performance.
#    * Using Python to check performance metrics (e.g., query execution time).
# *  Transactions:
#    * Explanation of transactions and why they are important.
#    * Implementing transactions in Python (using commit() and rollback()).
#    * Handling Large Datasets:
#    * Working with bulk inserts and pagination in SQL using Python.
# 6. Real-World Example: Creating a Simple App
# * Project: Create a small project where users interact with a database (e.g., a to-do list or a student management system).

# %% [markdown]
# ## Introduction to SQL and Databases
